# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("final_data.csv")
df.sample(5)
# Out:
#                                                    text  setiment
# 2448  That topped consensus forecasts for earnings o...  positive
# 1802  In a release , the Company said that Vocollect...  positive
# 449   Device volume in the area decreased by 21 % to...  negative
# 2353  Sales increased due to growing market rates an...  positive
# 503   The Group 's order portfolio decreased from EU...  negative

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# text        0
# setiment    0
# dtype: int64

# %%
df.shape
# Out:
# (2550, 2)

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re

# %%
#text preprocessing


def preprocessing(text):
    ps = PorterStemmer()
    text = text.lower()
    text = re.sub('[0-9]+', '', text)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub('[^a-zA-Z]',' ',text)
    text = [ps.stem(word) for word in text.split() if word not in set(stopwords.words('english'))]
    text = ' '.join(text)
    return text

# %%
df['text'] = df['text'].apply(preprocessing)

# %%
df.sample(5)
# Out:
#                                                    text  setiment
# 1583  nordea bank larg share vast experi nordic cred...   neutral
# 1899  one instal elev doubl deck elev enabl effici u...  positive
# 965   negoti concern personnel cencorp corpor singul...   neutral
# 1751  okmet product base high tech expertis gener ad...  positive
# 1959  agenciesemkay global financi servic buy call h...  positive

# %%
df.duplicated().sum()
# Out:
# np.int64(27)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# text        0
# setiment    0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# text        0
# setiment    0
# dtype: int64

# %%
df.to_csv("preprocessed_data.csv",index=False)

# %%
df.shape
# Out:
# (2523, 2)
